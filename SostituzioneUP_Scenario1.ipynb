# %%
import pandas as pd
import folium
import random
from shapely.geometry import Point
import geopandas as gpd
from geopy.distance import geodesic

# %%
# Generazione dati fittizi per UP (Uffici Postali)
n_up = 10
up_data = {
    "id": [f"UP_{i}" for i in range(n_up)],
    "lat": [random.uniform(45.0, 45.2) for _ in range(n_up)],
    "lon": [random.uniform(9.0, 9.2) for _ in range(n_up)],
    "produzione_totale": [random.randint(5000, 20000) for _ in range(n_up)],
    "bollettini": [random.randint(1000, 5000) for _ in range(n_up)],
    "pagoPA_MAV": [random.randint(500, 3000) for _ in range(n_up)],
    "ricariche_postepay": [random.randint(500, 2000) for _ in range(n_up)],
    "pacchi": [random.randint(300, 1500) for _ in range(n_up)],
}
df_up = pd.DataFrame(up_data)

# %%
df_up
# Out:
#      id        lat       lon  produzione_totale   bollettini  pagoPA_MAV  \
# 1  UP_1  45.004090  9.131227               7348  2117.000000        2925
# 2  UP_2  45.047516  9.096861              14970  1916.000000         594
# 3  UP_3  45.045422  9.037004               5692  2706.000000        1331
# 4  UP_4  45.133195  9.109110              15721  2148.166667        1770
# 5  UP_5  45.197443  9.099580              13007  4883.166667        1864
# 6  UP_6  45.029753  9.088834               6059  3774.000000        2740
# 7  UP_7  45.099661  9.146675              13136  4392.000000         904
# 8  UP_8  45.047337  9.191387              18367  2968.000000         984
# 9  UP_9  45.198323  9.031120              17848  5492.166667        1531
#
#    ricariche_postepay  pacchi
# 1                1119     571
# 2                1604    1167
# 3                1426     881
# 4                 847    1265
# 5                 894    1101
# 6                1781    1100
# 7                1194    1427
# 8                 926     769
# 9                1140    1474

# %%
# Generazione dati fittizi per LIS (punti vendita autorizzati)
n_lis = 15
lis_data = {
    "id": [f"LIS_{i}" for i in range(n_lis)],
    "lat": [random.uniform(45.0, 45.2) for _ in range(n_lis)],
    "lon": [random.uniform(9.0, 9.2) for _ in range(n_lis)],
    "abilitazione_bollettini": [random.choice([True, False]) for _ in range(n_lis)],
    "abilitazione_pagoPA_MAV": [random.choice([True, False]) for _ in range(n_lis)],
    "abilitazione_ricariche_postepay": [random.choice([True, False]) for _ in range(n_lis)],
    "abilitazione_pacchi": [random.choice([True, False]) for _ in range(n_lis)],
}
df_lis = pd.DataFrame(lis_data)

# %%
df_lis
# Out:
#         id        lat       lon  abilitazione_bollettini  \
# 0    LIS_0  45.161381  9.116740                     True
# 1    LIS_1  45.137879  9.019965                    False
# 2    LIS_2  45.120830  9.060033                     True
# 3    LIS_3  45.078096  9.119793                     True
# 4    LIS_4  45.152058  9.027327                    False
# 5    LIS_5  45.083519  9.054631                     True
# 6    LIS_6  45.159394  9.029146                    False
# 7    LIS_7  45.134174  9.034063                    False
# 8    LIS_8  45.162697  9.071186                     True
# 9    LIS_9  45.070289  9.024430                     True
# 10  LIS_10  45.000181  9.142443                     True
# 11  LIS_11  45.028673  9.112009                     True
# 12  LIS_12  45.110079  9.153388                    False
# 13  LIS_13  45.016501  9.137362                    False
# 14  LIS_14  45.102128  9.175440                     True
#
#     abilitazione_pagoPA_MAV  abilitazione_ricariche_postepay  \
# 0                      True                             True
# 1                     False                             True
# 2                     False                             True
# 3                      True                             True
# 4                      True                             True
# 5                      True                             True
# 6                      True                            False
# 7                      True                             True
# 8                     False                            False
# 9                      True                            False
# 10                     True                             True
# 11                    False                            False
# 12                     True                             True
# 13                    False                             True
# 14                    False                             True
#
#     abilitazione_pacchi
# 0                 False
# 1                  True
# 2                 False
# 3                  True
# 4                  True
# 5                 False
# 6                  True
# 7                 False
# 8                 False
# 9                 False
# 10                False
# 11                 True
# 12                False
# 13                False
# 14                 True

# %%
# Generazione dati fittizi per Banche
n_banche = 8
banche_data = {
    "id": [f"BANCA_{i}" for i in range(n_banche)],
    "lat": [random.uniform(45.0, 45.2) for _ in range(n_banche)],
    "lon": [random.uniform(9.0, 9.2) for _ in range(n_banche)],
    "gruppo_bancario": [random.choice(["Gruppo A", "Gruppo B", "Gruppo C"]) for _ in range(n_banche)],
    "peso_competitivo": [random.uniform(0.5, 1.5) for _ in range(n_banche)],
}
df_banche = pd.DataFrame(banche_data)

# %%
# Funzione per calcolare la distanza geografica
def calcola_distanza(coord1, coord2):
    return geodesic(coord1, coord2).meters

# %%
# Simulazione chiusura di un UP
up_da_chiudere = df_up.iloc[0]  # Selezioniamo il primo UP per la chiusura
df_up = df_up[df_up["id"] != up_da_chiudere["id"]]  # Rimuoviamo l'UP chiuso

# %%
# Redistribuzione della produzione
percentuale_up = 0.5  # 50% della produzione va agli UP vicini
percentuale_lis = 0.3  # 30% va agli LIS abilitati
percentuale_competitor = 0.1  # 10% passa ai competitor
percentuale_digitale = 0.1  # 10% passa al digitale

# %%
# Trova gli UP e LIS più vicini
up_limitrofi = df_up.copy()
up_limitrofi["distanza"] = up_limitrofi.apply(lambda row: calcola_distanza((up_da_chiudere["lat"], up_da_chiudere["lon"]), (row["lat"], row["lon"])), axis=1)
up_limitrofi = up_limitrofi.sort_values("distanza").head(3)  # Consideriamo i 3 UP più vicini

lis_limitrofi = df_lis.copy()
lis_limitrofi["distanza"] = lis_limitrofi.apply(lambda row: calcola_distanza((up_da_chiudere["lat"], up_da_chiudere["lon"]), (row["lat"], row["lon"])), axis=1)
lis_limitrofi = lis_limitrofi.sort_values("distanza").head(3)  # Consideriamo i 3 LIS più vicini

# %%
# Assicuriamoci che LIS abbia le stesse colonne di produzione di UP
for col in ["bollettini", "pagoPA_MAV", "ricariche_postepay", "pacchi"]:
    if col not in df_lis.columns:
        df_lis[col] = 0  # Creiamo le colonne mancanti con valore 0

# %%
# Distribuzione della produzione tra UP e LIS limitrofi
for col in ["bollettini", "pagoPA_MAV", "ricariche_postepay", "pacchi"]:
    produzione = up_da_chiudere[col]
    quota_up = produzione * percentuale_up / len(up_limitrofi)
    quota_lis = produzione * percentuale_lis / len(lis_limitrofi)
    
    df_up.loc[up_limitrofi.index, col] += quota_up
    df_lis.loc[lis_limitrofi.index, col] = df_lis.loc[lis_limitrofi.index, col].fillna(0) + quota_lis
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_23268\3010420888.py:8: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[313.9 313.9 313.9]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df_lis.loc[lis_limitrofi.index, col] = df_lis.loc[lis_limitrofi.index, col].fillna(0) + quota_lis
# C:\Users\User\AppData\Local\Temp\ipykernel_23268\3010420888.py:8: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[102.6 102.6 102.6]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df_lis.loc[lis_limitrofi.index, col] = df_lis.loc[lis_limitrofi.index, col].fillna(0) + quota_lis
# C:\Users\User\AppData\Local\Temp\ipykernel_23268\3010420888.py:7: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[1422.83333333 1176.83333333 1129.83333333]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df_up.loc[up_limitrofi.index, col] += quota_up
# C:\Users\User\AppData\Local\Temp\ipykernel_23268\3010420888.py:8: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[169.7 169.7 169.7]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df_lis.loc[lis_limitrofi.index, col] = df_lis.loc[lis_limitrofi.index, col].fillna(0) + quota_lis
# C:\Users\User\AppData\Local\Temp\ipykernel_23268\3010420888.py:7: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[1648.5 1275.5 1439.5]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df_up.loc[up_limitrofi.index, col] += quota_up
# C:\Users\User\AppData\Local\Temp\ipykernel_23268\3010420888.py:8: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[104.7 104.7 104.7]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df_lis.loc[lis_limitrofi.index, col] = df_lis.loc[lis_limitrofi.index, col].fillna(0) + quota_lis

# %%
# Creazione della mappa
mappa = folium.Map(location=[45.1, 9.1], zoom_start=12)

# %%
# Aggiunta UP
for _, row in df_up.iterrows():
    folium.Marker(
        location=[row['lat'], row['lon']],
        popup=f"{row['id']} - Produzione: {row['produzione_totale']}",
        icon=folium.Icon(color="blue", icon="envelope")
    ).add_to(mappa)

# Aggiunta LIS
for _, row in df_lis.iterrows():
    folium.Marker(
        location=[row['lat'], row['lon']],
        popup=f"{row['id']}",
        icon=folium.Icon(color="green", icon="shopping-cart")
    ).add_to(mappa)

# Aggiunta Banche
for _, row in df_banche.iterrows():
    folium.Marker(
        location=[row['lat'], row['lon']],
        popup=f"{row['id']} - {row['gruppo_bancario']}",
        icon=folium.Icon(color="red", icon="usd")
    ).add_to(mappa)

# %%
# Salvataggio mappa
mappa.save("mappa_simulazione_scenario.html")
mappa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b4b94f87fa460646f684ee30b37945d3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b4b94f87fa460646f684ee30b37945d3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b4b94f87fa460646f684ee30b37945d3 = L.map(
#                 &quot;map_b4b94f87fa460646f684ee30b37945d3&quot;,
#                 {
#                     center: [45.1, 9.1],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d517caaabf51f46e4f5e388f40a74d2d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d517caaabf51f46e4f5e388f40a74d2d.addTo(map_b4b94f87fa460646f684ee30b37945d3);
#
#
#             var marker_ee99dbe9dcf7369dcb4962fe29bbcd5c = L.marker(
#                 [45.00409014775021, 9.131227468751023],
#                 {
# }
#             ).addTo(map_b4b94f87fa460646f684ee30b37945d3);
#
#
#             var icon_16e1140458b1e42b63faa5c01901453c = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;envelope&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_09dbb891431b277901b97b4422a66a0b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_525f87ae4f4e7e897ed811aee4dc3705 = $(`&lt;div id=&quot;html_525f87ae4f4e7e897ed811aee4dc3705&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;UP_1 - Produzione: 7348&lt;/div&gt;`)[0];
#                 popup_09dbb891431b277901b97b4422a66a0b.setContent(html_525f87ae4f4e7e897ed811aee4dc3705);
#
#
#
#         marker_ee99dbe9dcf7369dcb4962fe29bbcd5c.bindPopup(popup_09dbb891431b277901b97b4422a66a0b)
#         ;
#
#
#
#
#                 marker_ee99dbe9dcf7369dcb4962fe29bbcd5c.setIcon(icon_16e1140458b1e42b63faa5c01901453c);
#
#
#             var marker_54d6b43be44462734f43c17ef11e9e6f = L.marker(
#                 [45.0475156903645, 9.096861320103455],
#                 {
# }
#             ).addTo(map_b4b94f87fa460646f684ee30b37945d3);
#
#
#             var icon_4ee38db639bdf553913fb2e8a87be789 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;envelope&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_1582f1e07cac3acb706afdf561dc4c93 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d00f2254e9013a77ce821048808e4239 = $(`&lt;div id=&quot;html_d00f2254e9013a77ce821048808e4239&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;UP_2 - Produzione: 14970&lt;/div&gt;`)[0];
#                 popup_1582f1e07cac3acb706afdf561dc4c93.setContent(html_d00f2254e9013a77ce821048808e4239);
#
#
#
#         marker_54d6b43be44462734f43c17ef11e9e6f.bindPopup(popup_1582f1e07cac3acb706afdf561dc4c93)
#         ;
#
#
#
#
#                 marker_54d6b43be44462734f43c17ef11e9e6f.setIcon(icon_4ee38db639bdf553913fb2e8a87be789);
#
#
#             var marker_02db917ee75cd951224deaed1a3878bd = L.marker(
#                 [45.04542228680654, 9.037003849382485],
#                 {
# }
#             ).addTo(map_b4b94f87fa460646f684ee30b37945d3);
#
#
#             var icon_0c0e4868a95f55b71561e1e4d1ae0cd6 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;envelope&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_ae183d93bcc6f9626bc2a5c285c9c1b6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e5cf900ecdebbb8c9a66082ca22194d9 = $(`&lt;div id=&quot;html_e5cf900ecdebbb8c9a66082ca22194d9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;UP_3 - Produzione: 5692&lt;/div&gt;`)[0];
#                 popup_ae183d93bcc6f9626bc2a5c285c9c1b6.setContent(html_e5cf900ecdebbb8c9a66082ca22194d9);
#
#
#
#         marker_02db917ee75cd951224deaed1a3878bd.bindPopup(popup_ae183d93bcc6f9626bc2a5c285c9c1b6)
#         ;
#
#
#
#
#                 marker_02db917ee75cd951224deaed1a3878bd.setIcon(icon_0c0e4868a95f55b71561e1e4d1ae0cd6);
#
#
#             var marker_859d0c785912ae4a1c6b01e434216214 = L.marker(
#                 [45.13319451207638, 9.10910966654095],
#                 {
# }
#             ).addTo(map_b4b94f87fa460646f684ee30b37945d3);
